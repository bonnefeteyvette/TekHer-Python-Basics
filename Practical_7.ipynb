# %% [markdown]
# # Practical_7: Matplotlib

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a simple line plot for `y = x` for `x` values ranging from 0 to 10.

# %%
# Exercise 1
x = (1, 10)
y = x
plt.plot(x, y, "c")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 2:
# Plot `y = x^2` using Matplotlib for `x` values between -10 and 10.

# %%
# Exercise 2
x = np.linspace(-10, 10)
y = x ** 2

plt.plot(x, y, 'c')

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 3:
# Create a scatter plot with 50 random points where x and y values are between 0 and 10.

# %%
# Exercise 3
x = np.random.uniform(0, 10, 50)
y = np.random.uniform(0, 10, 50)

plt.scatter(x, y, color ='darkcyan')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter Plot of 50 random point')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 4:
# Plot a sine wave using Matplotlib for `x` values between 0 and 2π.

# %%
# Exercise 4
x = np.linspace(0, 2 * np.pi)
y = np.sin(x)

plt.plot(x, y, "o:c")
plt.xlabel('x values')
plt.ylabel('sin(x)')
plt.title('Sine Wave')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 5:
# Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 5
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
color = ['cyan']
plt.bar(categories, values, color = 'darkcyan')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart of Categories and Values')
plt.show()

# %%
# Exercise 5

# %% [markdown]
# ---
#
# ### Exercise 6:
# Create a histogram of 1000 random numbers generated from a normal distribution.

# %%
# Exercise 6
data = np.random.randn(1000)

plt.hist(data, bins=30, color='darkcyan')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 1000 Random Numbers from a Normal Distribution')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 7:
# Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.

# %%
# Exercise 7
x = np.linspace(0, 10, 100)
y1 = x**2
y2 = x**3

plt.plot(x, y1, color ='darkcyan')
plt.plot(x, y2, color ='green')
plt.title('Two line plots')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 8:
# Add titles, axis labels, and a legend to the plot in Exercise 7.

# %%
# Exercise 8

x = np.linspace(0, 10, 100)
y1 = x**2
y2 = x**3

plt.plot(x, y1, label='$y = x^2$', color ='darkcyan')
plt.plot(x, y2, label='$y = x^3$', color ='darkgreen')

plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Plot of $y = x^2$ and $y = x^3$')
plt.legend()

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 9:
# Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.

# %%
# Exercise 9
x = np.linspace(0, 10, 100)
y1 = x**2
y2 = x**3

fig, axes = plt.subplots(2, 1)

axes[0].plot(x, y1, color='darkcyan')
axes[1].plot(x, y2, color='darkcyan')

axes[0].set_title('Plot of $y = x^2$')
axes[1].set_title('Plot of $y = x^3$')

axes[0].set_xlabel('x values')
axes[0].set_ylabel('y values')

axes[1].set_xlabel('x values')
axes[1].set_ylabel('y values')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 10:
# Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.

# %%
# Exercise 10
x = np.linspace(0, 10, 100)
y1 = x
y2 = x**2
y3 = x**3

plt.plot(x, y1, color='darkorange', linestyle='-', label='$y = x$')
plt.plot(x, y2, color='darkblue', linestyle='--', label='$y = x^2$')
plt.plot(x, y3, color='darkgreen', linestyle='-.', label='$y = x^3$')

plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Plots of y = x, $y = x^2$, and $y = x^3$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 11:
# Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.

# %%
# Exercise 11
sizes = [25, 35, 20, 15, 5]
labels = ['A', 'B', 'C', 'D', 'E']
colors = ['darkcyan', 'grey', 'cyan', 'blue', 'orange']
explode = (0, 0, 0, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=120)

plt.axis('equal')
plt.title('Pie Chart of Segments')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 12:
# Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 12
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]

plt.barh(categories, values, color='darkcyan')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Chart of Categories and Values')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 13:
# Change the figure size of a line plot to 10x6 inches.

# %%
# Exercise 13
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))

plt.plot(x, y, color='darkcyan')
plt.xlabel('x values')
plt.ylabel('sin(x)')
plt.title('Sine Wave with Custom Figure Size')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 14:
# Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.

# %%
# Exercise 14
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y, label='y = x^2', color='darkcyan')
plt.fill_between(x, y, color='gray', alpha=0.5)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Filled Area Under y = x^2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 15:
# Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.

# %%
# Exercise 15
plt.style.use('ggplot')

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y, label='y = sin(x)', color='darkcyan')
plt.fill_between(x, y, color='grey', alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine Wave with ggplot Style')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 16:
# Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.

# %%
# Exercise 16
group_a = np.array([3, 5, 7])
group_b = np.array([2, 6, 4])
categories = ['X', 'Y', 'Z']

plt.bar(categories, group_a, label='Group A', color='darkcyan')
plt.bar(categories, group_b, bottom=group_a, label='Group B', color='cyan')

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Chart of Group A and Group B')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a plot with multiple subplots in a 2x2 grid. Plot `y1 = x`, `y2 = x^2`, `y3 = x^3`, and `y4 = x^4`.

# %%
# Exercise 17
x = np.linspace(0, 10, 100)
y1 = x
y2 = x**2
y3 = x**3
y4 = x**4

fig, axes = plt.subplots(2, 2)

axes[0, 0].plot(x, y1)
axes[0, 0].set_title('$y = x$')
axes[0, 0].set_xlabel('x values')
axes[0, 0].set_ylabel('y values')
axes[0, 0].grid(True)

axes[0, 1].plot(x, y2, color='cyan')
axes[0, 1].set_title('$y = x^2$')
axes[0, 1].set_xlabel('x values')
axes[0, 1].set_ylabel('y values')
axes[0, 1].grid(True)


axes[1, 0].plot(x, y3, color='darkcyan')
axes[1, 0].set_title('$y = x^3$')
axes[1, 0].set_xlabel('x values')
axes[1, 0].set_ylabel('y values')
axes[1, 0].grid(True)


axes[1, 1].plot(x, y4, color='green')
axes[1, 1].set_title('$y = x^4$')
axes[1, 1].set_xlabel('x values')
axes[1, 1].set_ylabel('y values')
axes[1, 1].grid(True)


plt.tight_layout() # Adjust layout to prevent titles/labels overlapping
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 18:
# Create a heatmap using a 2D array of random values with shape (5, 5).

# %%
# Exercise 18
data = np.random.rand(5, 5)
plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Value')
plt.title('Heatmap of 5x5 Random Data')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.

# %%
# Exercise 19
categories = ['A', 'B', 'C', 'D']
values = np.array([3, 7, 5, 9])
error = np.array([1, 1, 1, 1])

plt.bar(categories, values, yerr=error, capsize=5, color='darkcyan')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Error Bars')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 20:
# Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.

# %%
# Exercise 20
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, linestyle='--', label='Sine Wave', color='cyan')
plt.plot(x, y_cos, linestyle='-', label='Cosine Wave', color='darkcyan')

plt.xlabel('x values')
plt.ylabel('Amplitude')
plt.title('Sine and Cosine Waves')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 21:
# Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.

# %%
# Exercise 21
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)

plt.contour(X, Y, Z, levels=20, cmap='cividis')
plt.colorbar(label='Z value')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Contour Plot of z = sin(x) + cos(y)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 22:
# Create a box plot for a dataset generated with 100 random numbers from a normal distribution.

# %%
# Exercise 22
data = np.random.randn(100)

plt.boxplot(data)
plt.ylabel('Value')
plt.title('Box Plot of 100 Random Numbers from Normal Distribution')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a scatter plot with a color map applied to the points, where the color represents the value of the points.

# %%
# Exercise 23
np.random.seed(42)
x = np.random.rand(50) * 10
y = np.random.rand(50) * 10
colors = np.random.rand(50)

plt.scatter(x, y, c=colors, cmap='YlGnBu')
plt.colorbar(label='Color Value')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter Plot with Color Mapping')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 24:
# Use Matplotlib to display an image from a file.

# %%
# Exercise 24
from PIL import Image

try:
    img = Image.new('RGB', (60, 30), color = 'red')
    img.save('balimage.png')
    print("Created a dummy image file 'balimage.png'.")
except ImportError:
    print("Pillow library not found. Please install it (`pip install Pillow`) to create a dummy image.")
    print("You will need an image file (e.g., 'balimage.png') in the same directory to run the rest of this cell.")

try:
    img_data = plt.imread(r"C:\Users\Tasha\Desktop\TekHer-Python-Basics\balconies.png")

    # Display the image
    plt.imshow(img_data)
    plt.title('Image Displayed with Matplotlib')
    plt.axis('off')
    plt.show()

except FileNotFoundError:
    print("Error: 'balimage.png' not found. Please make sure the image file is in the same directory as your notebook or provide the full path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Created a dummy image file 'balimage.png'.

# %% [markdown]
# ---
#
# ### Exercise 25:
# Create a plot with logarithmic scaling on both axes.

# %%
# # Exercise 25
x = np.linspace(1, 100, 100)
y = x**2

plt.figure()
plt.plot(x, y, color ='darkcyan')

plt.xscale('log')
plt.yscale('log')

plt.xlabel('x (log scale)')
plt.ylabel('y (log scale)')
plt.title('Plot with Logarithmic Axes')
plt.grid(True, which="both", ls="-")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 26:
# Create a 3D plot of the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 26
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot of z = x^2 + y^2')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 27:
# Create a radar chart with 5 variables and random values between 0 and 1.

# %%
# Exercise 27

import numpy as np
import matplotlib.pyplot as plt

num_vars = 5

values = np.random.rand(num_vars)
values = np.append(values, values[0])

labels = [f'Var {i+1}' for i in range(num_vars)]

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

ax.fill(angles, values, color='gray', alpha=0.4)
ax.plot(angles, values, color='darkcyan', linewidth=2)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.set_yticklabels([])
plt.title('Radar Chart with Random Values')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 28:
# Create a violin plot to show the distribution of a dataset generated with 1000 random numbers from a normal distribution.

# %%
# Exercise 28
data = np.random.randn(1000)

plt.violinplot(data, showmeans=True, showmedians=True)

plt.ylabel('Value')
plt.title('Violin Plot of 1000 Random Numbers from Normal Distribution')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 29:
# Create a bar chart with different colors for each bar.

# %%
# Exercise 29
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
colors = ['darkcyan', 'cyan', 'green', 'lightgreen']

plt.bar(categories, values, color=colors)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Different Bar Colors')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 30:
# Create a stem plot for the function `y = sin(x)` for `x` values between 0 and 2π.

# %%
# Exercise 30
x = np.linspace(0, 2 * np.pi, 20)
y = np.sin(x)

plt.stem(x, y)
plt.xlabel('x values')
plt.ylabel('sin(x)')
plt.title('Stem Plot of y = sin(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 31:
# Create a scatter plot with markers of different sizes.

# %%
# Exercise 31
np.random.seed(42)
x = np.random.rand(50) * 10
y = np.random.rand(50) * 10
sizes = np.random.rand(50) * 500

plt.scatter(x, y, s=sizes, color='darkcyan')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Scatter Plot with Different Marker Sizes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 32:
# Plot a cumulative histogram of 1000 random numbers generated from a uniform distribution.

# %%
# Exercise 32
data = np.random.rand(1000)

plt.hist(data, bins=30, cumulative=True,color='darkcyan', density=True)
plt.xlabel('Value')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Histogram of 1000 Random Numbers from Uniform Distribution')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 33:
# Create a pie chart with custom colors for each segment.

# %%
# Exercise 33
sizes = [25, 35, 20, 15, 5]
labels = ['A', 'B', 'C', 'D', 'E']
colors = ['green', 'darkcyan', 'indigo', 'lightskyblue', 'darkorange']

plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.title('Pie Chart with Custom Colors')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 34:
# Create a plot with twin y-axes where one axis represents `y = x` and the other represents `y = x^2`.

# %%
# Exercise 34
x = np.linspace(0, 10, 100)
y1 = x
y2 = x**2

fig, ax1 = plt.subplots()

ax1.plot(x, y1, color='darkcyan', label='$y = x$')
ax1.set_xlabel('x values')
ax1.set_ylabel('$y = x$', color='black')
ax1.tick_params(axis='y', labelcolor='black')

ax2 = ax1.twinx()

ax2.plot(x, y2, color='cyan', label='$y = x^2$')
ax2.set_ylabel('$y = x^2$', color='black')
ax2.tick_params(axis='y', labelcolor='black')

plt.title('Plot with Twin Y-Axes (y=x and y=x^2)')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 35:
# Plot a density plot of 1000 random values from a normal distribution.

# %%
# Exercise 35
import seaborn as

data = np.random.randn(1000)

plt.figure(figsize=(8, 6))
sns.kdeplot(data, fill=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Density Plot of 1000 Random Numbers from Normal Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 36:
# Create a histogram and add a kernel density estimate (KDE) to the plot.

# %%
# Exercise 36
data = np.random.randn(1000)

plt.hist(data, bins=30, density=True, alpha=0.6, color='darkcyan', label='Histogram')

import seaborn as sns
sns.kdeplot(data, color='c', label='KDE')

plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram with KDE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---
#
# ### Exercise 37:
# Add gridlines to a line plot and change the color and linestyle of the grid.

# %%
# Exercise 37
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Line Plot with Custom Gridlines')

# Add gridlines and change their color and linestyle
plt.grid(True, color='darkcyan', linestyle='--', linewidth=0.5)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 38:
# Create a bar chart with annotations showing the height of each bar above the bar.

# %%
# Exercise 38
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]

plt.bar(categories, values, color='darkcyan')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Annotations')

for i, value in enumerate(values):
    plt.text(i, value + 0.2, str(value), ha='center')

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 39:
# Create a filled contour plot for the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 39
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

plt.contourf(X, Y, Z, levels=20, cmap='cividis')
plt.colorbar(label='Z value')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Filled Contour Plot of z = x^2 + y^2')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 40:
# Create a stacked area plot using three random datasets.

# %%
# Exercise 40
np.random.seed(42)
x = np.linspace(0, 10, 100)
y1 = np.random.rand(100) * 5
y2 = np.random.rand(100) * 5
y3 = np.random.rand(100) * 5

# Create the stacked area plot
plt.stackplot(x, y1, y2, y3, labels=['Dataset 1', 'Dataset 2', 'Dataset 3'], alpha=0.8)

plt.xlabel('x values')
plt.ylabel('Values')
plt.title('Stacked Area Plot of Three Datasets')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 41:
# Create a bar chart with error bars, where the error values are proportional to the bar values.

# %%
# Exercise 41
categories = ['A', 'B', 'C', 'D']
values = np.array([3, 7, 5, 9])
error = values * 0.1

plt.bar(categories, values, yerr=error, capsize=5, color='darkcyan')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Proportional Error Bars')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 42:
# Create a wind rose chart using random wind direction and speed data.

# %%
# !pip install windrose
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Exercise 42
try:
    from windrose import WindroseAxes
    np.random.seed(42)
    wind_direction = np.random.rand(500) * 360
    wind_speed = np.random.rand(500) * 20 + 1

    fig = plt.figure(figsize=(8, 8))
    ax = WindroseAxes.from_ax(fig=fig)

    ax.bar(wind_direction, wind_speed, normed=True, opening=0.8, edgecolor='white')
    ax.set_title('Wind Rose Chart')

    ax.set_legend()

    plt.show()

except ImportError:
    print("The 'windrose' library is required for this exercise.")
    print("Please install it using: !pip install windrose")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ---
#
# ### Exercise 43:
# Plot a cumulative frequency curve for a dataset of 100 random numbers.

# %%
# Exercise 43
import numpy as np
import matplotlib.pyplot as plt

# Generate 100 random numbers
data = np.random.rand(100)

# Sort the data
data_sorted = np.sort(data)

cumulative_freq = np.arange(1, 101) / 100

plt.figure(figsize=(8, 5))
plt.plot(data_sorted, cumulative_freq, marker='o', linestyle='-', color='darkcyan')

plt.xlabel('Data Values')
plt.ylabel('Cumulative Frequency')
plt.title('Cumulative Frequency Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 44:
# Create a waterfall chart using Matplotlib to show the changes in a sequence of values.

# %%
# Exercise 44
labels = ['Start', 'Increase 1', 'Decrease 1', 'Increase 2', 'End']
values = [100, 20, -30, 15, 105]

cumulative_values = np.cumsum(values[:-1])

change_values = np.array(values[1:-1])
bar_heights = np.abs(change_values)
bar_bottoms = cumulative_values[:-1]
bar_bottoms = np.insert(bar_bottoms, 0, values[0])

bar_colors = ['green' if change > 0 else 'lightgreen' for change in change_values]
bar_colors.insert(0, 'darkcyan')
bar_colors.append('darkcyan')

fig, ax = plt.subplots(figsize=(8, 6))

# Plot the starting bar
ax.bar(labels[0], values[0], color=bar_colors[0])

for i in range(len(change_values)):
    if change_values[i] > 0:
        ax.bar(labels[i+1], bar_heights[i], bottom=bar_bottoms[i], color=bar_colors[i+1])
    else:
        ax.bar(labels[i+1], -bar_heights[i], bottom=bar_bottoms[i] + bar_heights[i], color=bar_colors[i+1])

end_value = values[-1]

ax.bar(labels[-1], end_value, color=bar_colors[-1])

for i in range(len(values) - 1):
    start_y = values[i] if i == 0 else cumulative_values[i-1] + change_values[i-1]
    end_y = cumulative_values[i]

    ax.hlines(start_y, i, i + 1, color='grey', linestyle='--')


ax.set_xlabel('Categories')
ax.set_ylabel('Value')
ax.set_title('Simple Waterfall Chart')
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 45:
# Use the `imshow` function to display a 10x10 matrix of random values as an image.

# %%
# Exercise 45
data = np.random.rand(10, 10) # Create a 10x10 array of random values between 0 and 1

plt.imshow(data, cmap='cividis', interpolation='nearest') # Display the matrix as an image
plt.colorbar(label='Value') # Add a color bar to show the mapping
plt.title('10x10 Matrix as Image (imshow)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 46:
# Create a line plot with different markers for each point.

# %%
# Exercise 46
x = np.linspace(0, 10, 20)
y = np.sin(x)

markers = ['o', 'v', '^', '<', '>', 's', 'p', '*', 'h', '+', 'x', 'D', 'd', '|', '_']

plt.figure(figsize=(10, 6))

for i in range(len(x)):
    plt.plot(x[i], y[i], marker=markers[i % len(markers)], color='darkcyan')
plt.xlabel('x values')
plt.ylabel('sin(x)')
plt.title('Line Plot with Different Markers for Each Point')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(x, y, linestyle='-', color='darkcyan', marker='o')
plt.xlabel('x values')
plt.ylabel('sin(x)')
plt.title('Line Plot with Standard Markers')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 47:
# Create a time series plot using Matplotlib and plot random data over a range of dates.

# %%
# Exercise 47
import pandas as pd

dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
np.random.seed(42)
data = np.random.randn(100).cumsum()

plt.figure(figsize=(10, 6))
plt.plot(dates, data)

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Time Series Plot of Random Data')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 48:
# Create a bar chart with bars colored by category.

# %%
# Exercise 48
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
colors = ['darkcyan', 'darkgreen', 'green', 'lightgreen']

plt.bar(categories, values, color=colors)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Different Bar Colors by Category')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 49:
# Create a radar chart to visualize the strengths of five different attributes.

# %%
# Exercise 49
# This is essentially the same as Exercise 27, just rephrased.

# Define the number of attributes
num_attributes = 5

# Generate random values for each attribute (between 0 and 1, or scale as needed)
# Let's use random values scaled between 0 and 10 as example "strengths"
strengths = np.random.rand(num_attributes) * 10

# Define the angles for each attribute (evenly spaced around a circle)
# We need to close the circle by repeating the first angle and value for plotting
angles = np.linspace(0, 2 * np.pi, num_attributes, endpoint=False).tolist()
strengths = np.concatenate((strengths, [strengths[0]])) # Close the circle by adding the first value again
angles.append(angles[0])

# Define the labels for each attribute
attribute_labels = [f'Attribute {i+1}' for i in range(num_attributes)]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plot the data
ax.plot(angles, strengths, 'o-', linewidth=2)

# Fill the area under the plot
ax.fill(angles, strengths, alpha=0.25)

# Set the labels for each attribute
# Use angles[:-1] because the last angle is a repeat for plotting connectivity
ax.set_thetagrids(np.degrees(angles[:-1]), attribute_labels)

# Set the title
ax.set_title('Radar Chart of Five Attributes')

# Set the y-axis limits and labels (optional, adjust based on your data range)
# Assuming strengths are between 0 and 10
ax.set_ylim(0, 10)
ax.set_yticks(np.linspace(0, 10, 5)) # Example y-ticks

# Add a grid
ax.grid(True)

plt.show()

# %% [markdown]
# ---
#
# ### Exercise 50:
# Create a 3D scatter plot with random values for x, y, and z.

# %%
# Exercise 50

# Generate random data for x, y, and z
np.random.seed(42) # for reproducibility
x = np.random.rand(100) * 10
y = np.random.rand(100) * 10
z = np.random.rand(100) * 10

# Create a new figure and add a 3D subplot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Create the 3D scatter plot
ax.scatter(x, y, z, c=z, cmap='cividis', marker='o') # Color points based on their z value

# Set labels and title
ax.set_xlabel('X Value')
ax.set_ylabel('Y Value')
ax.set_zlabel('Z Value')
ax.set_title('3D Scatter Plot of Random Data')

# Add a color bar to show the mapping of color to z value
fig.colorbar(ax.scatter(x, y, z, c=z, cmap='viridis', marker='o'), label='Z Value')

plt.show()

# %% [markdown]
# ---
